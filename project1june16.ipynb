# %%
import numpy as np

# %%
#Pandas :powerful library used for data manuplilation and data analysis
import pandas as pd

# %%
#exploratory data analysis EDA 1 st of data analysis , It helps you understand the structure, patterns, anomalies, and relationships within a dataset.

# %%
data =pd.read_csv('project_excel file.csv')

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df=pd.DataFrame(data)

# %%
df.head() #pass 5 values
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.head() # First 5 rows
df.tail() # Last 5 rows
df.shape # Rows and columns
df.columns # Column names
df.info() # Data types and nulls
df.describe() # Statistical summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
#missing handling values
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.isnull()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
df.isna()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
df.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.dropna()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
#df.fillna(strategy=mean()) #fill the missing values using strategy
#df.isnull() #find the null values true r false
#df.isna()
#df.isnull().sum() #count the missung values
#df.dropna() #drop missing values
#df.fillna(0) #fill the missing values
#df['column'].fillna(df['column name'].mean(),inplace=True)

# %%
#Handling duplicate values

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Length: 30000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#df.drop_duplicates(inplace=True)

# %%
df['LIMIT_BAL']=df['LIMIT_BAL'].astype('float')

# %%
df.dtypes
# Out:
# ID                              int64
# LIMIT_BAL                     float64
# SEX                             int64
# EDUCATION                       int64
# MARRIAGE                        int64
# AGE                             int64
# PAY_0                           int64
# PAY_2                           int64
# PAY_3                           int64
# PAY_4                           int64
# PAY_5                           int64
# PAY_6                           int64
# BILL_AMT1                       int64
# BILL_AMT2                       int64
# BILL_AMT3                       int64
# BILL_AMT4                       int64
# BILL_AMT5                       int64
# BILL_AMT6                       int64
# PAY_AMT1                        int64
# PAY_AMT2                        int64
# PAY_AMT3                        int64
# PAY_AMT4                        int64
# PAY_AMT5                        int64
# PAY_AMT6                        int64
# default payment next month      int64
# ...

# %%
df=df.rename(columns={'PAY_0':'SEPT_PAY'})

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  SEPT_PAY  PAY_2  \
# 0          1    20000.0    2          2         1   24         2      2
# 1          2   120000.0    2          2         2   26        -1      2
# 2          3    90000.0    2          2         2   34         0      0
# 3          4    50000.0    2          2         1   37         0      0
# 4          5    50000.0    1          2         1   57        -1      0
# ...      ...        ...  ...        ...       ...  ...       ...    ...
# 29995  29996   220000.0    1          3         1   39         0      0
# 29996  29997   150000.0    1          3         2   43        -1     -1
# 29997  29998    30000.0    1          2         2   37         4      3
# 29998  29999    80000.0    1          3         1   41         1     -1
# 29999  30000    50000.0    1          2         1   46         0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
df=df.rename(columns={'PAY_0':'SEPT_PAY','PAY_2':'AUG_PAY','PAY_3':'JULY_PAY','PAY_4':'JUN_PAY','PAY_5':'MAY_PAY','PAY_6':'APR_PAY'})

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0    2          2         1   24         2        2
# 1          2   120000.0    2          2         2   26        -1        2
# 2          3    90000.0    2          2         2   34         0        0
# 3          4    50000.0    2          2         1   37         0        0
# 4          5    50000.0    1          2         1   57        -1        0
# ...      ...        ...  ...        ...       ...  ...       ...      ...
# 29995  29996   220000.0    1          3         1   39         0        0
# 29996  29997   150000.0    1          3         2   43        -1       -1
# 29997  29998    30000.0    1          2         2   37         4        3
# 29998  29999    80000.0    1          3         1   41         1       -1
# 29999  30000    50000.0    1          2         1   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'SEPT_PAY',
#        'AUG_PAY', 'JULY_PAY', 'JUN_PAY', 'MAY_PAY', 'APR_PAY', 'BILL_AMT1',
#        'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df=df.rename(columns={'BILL_AMT1':'SEPT_BILL','BILL_AMT2':'AUG_BILL','BILL_AMT3':'JULY_BILL','BILL_AMT4':'JUN_BILL','BILL_AMT5':'MAY_BILL','BILL_AMT6':'APR_BILL'})

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0    2          2         1   24         2        2
# 1          2   120000.0    2          2         2   26        -1        2
# 2          3    90000.0    2          2         2   34         0        0
# 3          4    50000.0    2          2         1   37         0        0
# 4          5    50000.0    1          2         1   57        -1        0
# ...      ...        ...  ...        ...       ...  ...       ...      ...
# 29995  29996   220000.0    1          3         1   39         0        0
# 29996  29997   150000.0    1          3         2   43        -1       -1
# 29997  29998    30000.0    1          2         2   37         4        3
# 29998  29999    80000.0    1          3         1   41         1       -1
# 29999  30000    50000.0    1          2         1   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  PAY_AMT1  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'SEPT_PAY',
#        'AUG_PAY', 'JULY_PAY', 'JUN_PAY', 'MAY_PAY', 'APR_PAY', 'SEPT_BILL',
#        'AUG_BILL', 'JULY_BILL', 'JUN_BILL', 'MAY_BILL', 'APR_BILL', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df=df.rename(columns={'PAY_AMT1':'SEPT_PAYMENT','PAY_AMT2':'AUG_PAYMENT','PAY_AMT3':'JULY_PAYMENT','PAY_AMT4':'JUN_PAYMENT','PAY_AMT5':'MAY_PAYMENT','PAY_AMT6':'APR_PAYMENT'})

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0    2          2         1   24         2        2
# 1          2   120000.0    2          2         2   26        -1        2
# 2          3    90000.0    2          2         2   34         0        0
# 3          4    50000.0    2          2         1   37         0        0
# 4          5    50000.0    1          2         1   57        -1        0
# ...      ...        ...  ...        ...       ...  ...       ...      ...
# 29995  29996   220000.0    1          3         1   39         0        0
# 29996  29997   150000.0    1          3         2   43        -1       -1
# 29997  29998    30000.0    1          2         2   37         4        3
# 29998  29999    80000.0    1          3         1   41         1       -1
# 29999  30000    50000.0    1          2         1   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
#column values need to be replaced

# %%
df.replace({'SEX':{1:'M',2:'F'}},inplace=True)

# %%
df
# Out:
#           ID  LIMIT_BAL SEX  EDUCATION  MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F          2         1   24         2        2
# 1          2   120000.0   F          2         2   26        -1        2
# 2          3    90000.0   F          2         2   34         0        0
# 3          4    50000.0   F          2         1   37         0        0
# 4          5    50000.0   M          2         1   57        -1        0
# ...      ...        ...  ..        ...       ...  ...       ...      ...
# 29995  29996   220000.0   M          3         1   39         0        0
# 29996  29997   150000.0   M          3         2   43        -1       -1
# 29997  29998    30000.0   M          2         2   37         4        3
# 29998  29999    80000.0   M          3         1   41         1       -1
# 29999  30000    50000.0   M          2         1   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
df.replace({'MARRIAGE':{1:'Married',2:'Single',3:'Others'}},inplace=True)

# %%
df
# Out:
#           ID  LIMIT_BAL SEX  EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F          2  Married   24         2        2
# 1          2   120000.0   F          2   Single   26        -1        2
# 2          3    90000.0   F          2   Single   34         0        0
# 3          4    50000.0   F          2  Married   37         0        0
# 4          5    50000.0   M          2  Married   57        -1        0
# ...      ...        ...  ..        ...      ...  ...       ...      ...
# 29995  29996   220000.0   M          3  Married   39         0        0
# 29996  29997   150000.0   M          3   Single   43        -1       -1
# 29997  29998    30000.0   M          2   Single   37         4        3
# 29998  29999    80000.0   M          3  Married   41         1       -1
# 29999  30000    50000.0   M          2  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
df.replace({'EDUCATION':{1:'UG',2:'PG',3:'HIGH_SCHOOL',4:'OTHERS',0:'PHD',5:'M.PHIL',6:'B.TECH'}},inplace=True)

# %%
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F           PG  Married   24         2        2
# 1          2   120000.0   F           PG   Single   26        -1        2
# 2          3    90000.0   F           PG   Single   34         0        0
# 3          4    50000.0   F           PG  Married   37         0        0
# 4          5    50000.0   M           PG  Married   57        -1        0
# ...      ...        ...  ..          ...      ...  ...       ...      ...
# 29995  29996   220000.0   M  HIGH_SCHOOL  Married   39         0        0
# 29996  29997   150000.0   M  HIGH_SCHOOL   Single   43        -1       -1
# 29997  29998    30000.0   M           PG   Single   37         4        3
# 29998  29999    80000.0   M  HIGH_SCHOOL  Married   41         1       -1
# 29999  30000    50000.0   M           PG  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
df.replace({'default payment next month':{1:'Yes',0:'No'}},inplace=True)

# %%
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F           PG  Married   24         2        2
# 1          2   120000.0   F           PG   Single   26        -1        2
# 2          3    90000.0   F           PG   Single   34         0        0
# 3          4    50000.0   F           PG  Married   37         0        0
# 4          5    50000.0   M           PG  Married   57        -1        0
# ...      ...        ...  ..          ...      ...  ...       ...      ...
# 29995  29996   220000.0   M  HIGH_SCHOOL  Married   39         0        0
# 29996  29997   150000.0   M  HIGH_SCHOOL   Single   43        -1       -1
# 29997  29998    30000.0   M           PG   Single   37         4        3
# 29998  29999    80000.0   M  HIGH_SCHOOL  Married   41         1       -1
# 29999  30000    50000.0   M           PG  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
df=df.rename(columns={'default payment next month':'Target'})

# %%
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F           PG  Married   24         2        2
# 1          2   120000.0   F           PG   Single   26        -1        2
# 2          3    90000.0   F           PG   Single   34         0        0
# 3          4    50000.0   F           PG  Married   37         0        0
# 4          5    50000.0   M           PG  Married   57        -1        0
# ...      ...        ...  ..          ...      ...  ...       ...      ...
# 29995  29996   220000.0   M  HIGH_SCHOOL  Married   39         0        0
# 29996  29997   150000.0   M  HIGH_SCHOOL   Single   43        -1       -1
# 29997  29998    30000.0   M           PG   Single   37         4        3
# 29998  29999    80000.0   M  HIGH_SCHOOL  Married   41         1       -1
# 29999  30000    50000.0   M           PG  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
target_value=df['Target'].value_counts()

# %%
target_value
# Out:
# Target
# No     23364
# Yes     6636
# Name: count, dtype: int64

# %%
a=df['SEX'].value_counts()

# %%
a
# Out:
# SEX
# F    18112
# M    11888
# Name: count, dtype: int64

# %%
b=df['EDUCATION'].value_counts()

# %%
b
# Out:
# EDUCATION
# PG             14030
# UG             10585
# HIGH_SCHOOL     4917
# M.PHIL           280
# OTHERS           123
# B.TECH            51
# PHD               14
# Name: count, dtype: int64

# %%
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F           PG  Married   24         2        2
# 1          2   120000.0   F           PG   Single   26        -1        2
# 2          3    90000.0   F           PG   Single   34         0        0
# 3          4    50000.0   F           PG  Married   37         0        0
# 4          5    50000.0   M           PG  Married   57        -1        0
# ...      ...        ...  ..          ...      ...  ...       ...      ...
# 29995  29996   220000.0   M  HIGH_SCHOOL  Married   39         0        0
# 29996  29997   150000.0   M  HIGH_SCHOOL   Single   43        -1       -1
# 29997  29998    30000.0   M           PG   Single   37         4        3
# 29998  29999    80000.0   M  HIGH_SCHOOL  Married   41         1       -1
# 29999  30000    50000.0   M           PG  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
df['EDUCATION'].unique()
# Out:
# array(['PG', 'UG', 'HIGH_SCHOOL', 'M.PHIL', 'OTHERS', 'B.TECH', 'PHD'],
#       dtype=object)

# %%
filtered_df=df[df['SEX']=='M']

# %%
filtered_df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 4          5    50000.0   M           PG  Married   57        -1        0
# 5          6    50000.0   M           UG   Single   37         0        0
# 6          7   500000.0   M           UG   Single   29         0        0
# 9         10    20000.0   M  HIGH_SCHOOL   Single   35        -2       -2
# 13        14    70000.0   M           PG   Single   30         1        2
# ...      ...        ...  ..          ...      ...  ...       ...      ...
# 29995  29996   220000.0   M  HIGH_SCHOOL  Married   39         0        0
# 29996  29997   150000.0   M  HIGH_SCHOOL   Single   43        -1       -1
# 29997  29998    30000.0   M           PG   Single   37         4        3
# 29998  29999    80000.0   M  HIGH_SCHOOL  Married   41         1       -1
# 29999  30000    50000.0   M           PG  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
f1 = df[(df['EDUCATION'] == 'PG') & (df['MARRIAGE'] == 'Married')]

# %%
f1
# Out:
#           ID  LIMIT_BAL SEX EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F        PG  Married   24         2        2
# 3          4    50000.0   F        PG  Married   37         0        0
# 4          5    50000.0   M        PG  Married   57        -1        0
# 21        22   120000.0   F        PG  Married   39        -1       -1
# 33        34   500000.0   F        PG  Married   54        -2       -2
# ...      ...        ...  ..       ...      ...  ...       ...      ...
# 29982  29983    90000.0   M        PG  Married   36         0        0
# 29983  29984    20000.0   M        PG  Married   44        -2       -2
# 29990  29991   140000.0   M        PG  Married   41         0        0
# 29991  29992   210000.0   M        PG  Married   34         3        2
# 29999  30000    50000.0   M        PG  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
#sorting

# %%
sort_s=df.sort_values(by='AGE')

# %%
sort_s
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 7141    7142    30000.0   F           PG   Single   21        -2       -2
# 27662  27663    20000.0   F           PG   Single   21        -1       -1
# 8490    8491    10000.0   M  HIGH_SCHOOL   Single   21         0        0
# 12556  12557    20000.0   F           PG  Married   21         1       -2
# 1471    1472    20000.0   M           PG   Single   21         0        0
# ...      ...        ...  ..          ...      ...  ...       ...      ...
# 29175  29176   160000.0   F  HIGH_SCHOOL  Married   74         0        0
# 246      247   250000.0   F           PG  Married   75         0       -1
# 25141  25142   210000.0   M           PG  Married   75         0        0
# 25136  25137   180000.0   M           UG  Married   75         1       -2
# 18245  18246   440000.0   M           UG  Married   79         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
grouped_df=df.groupby('MARRIAGE')['LIMIT_BAL'].mean()

# %%
grouped_df
# Out:
# MARRIAGE
# 0          132962.962963
# Married    182200.893184
# Others      98080.495356
# Single     156413.660737
# Name: LIMIT_BAL, dtype: float64

# %%
g=df.groupby('SEX')['LIMIT_BAL'].count()

# %%
g
# Out:
# SEX
# F    18112
# M    11888
# Name: LIMIT_BAL, dtype: int64

# %%
df['AGE1']=df['AGE'].apply(lambda x:x+1)

# %%
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F           PG  Married   24         2        2
# 1          2   120000.0   F           PG   Single   26        -1        2
# 2          3    90000.0   F           PG   Single   34         0        0
# 3          4    50000.0   F           PG  Married   37         0        0
# 4          5    50000.0   M           PG  Married   57        -1        0
# ...      ...        ...  ..          ...      ...  ...       ...      ...
# 29995  29996   220000.0   M  HIGH_SCHOOL  Married   39         0        0
# 29996  29997   150000.0   M  HIGH_SCHOOL   Single   43        -1       -1
# 29997  29998    30000.0   M           PG   Single   37         4        3
# 29998  29999    80000.0   M  HIGH_SCHOOL  Married   41         1       -1
# 29999  30000    50000.0   M           PG  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  MAY_BILL  APR_BILL  SEPT_PAYMENT  AUG_PAYMENT  \
# ...

# %%
df=df.drop('AGE1',axis=1) #drop a coloumn axis=1 and axis =0  dropping row

# %%
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  SEPT_PAY  AUG_PAY  \
# 0          1    20000.0   F           PG  Married   24         2        2
# 1          2   120000.0   F           PG   Single   26        -1        2
# 2          3    90000.0   F           PG   Single   34         0        0
# 3          4    50000.0   F           PG  Married   37         0        0
# 4          5    50000.0   M           PG  Married   57        -1        0
# ...      ...        ...  ..          ...      ...  ...       ...      ...
# 29995  29996   220000.0   M  HIGH_SCHOOL  Married   39         0        0
# 29996  29997   150000.0   M  HIGH_SCHOOL   Single   43        -1       -1
# 29997  29998    30000.0   M           PG   Single   37         4        3
# 29998  29999    80000.0   M  HIGH_SCHOOL  Married   41         1       -1
# 29999  30000    50000.0   M           PG  Married   46         0        0
#
#        JULY_PAY  JUN_PAY  ...  JUN_BILL  MAY_BILL  APR_BILL  SEPT_PAYMENT  \
# ...

# %%
df.describe() #entire statistical infomation
# Out:
#                  ID       LIMIT_BAL           AGE      SEPT_PAY       AUG_PAY  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667     35.485500     -0.016700     -0.133767
# std     8660.398374   129747.661567      9.217904      1.123802      1.197186
# min        1.000000    10000.000000     21.000000     -2.000000     -2.000000
# 25%     7500.750000    50000.000000     28.000000     -1.000000     -1.000000
# 50%    15000.500000   140000.000000     34.000000      0.000000      0.000000
# 75%    22500.250000   240000.000000     41.000000      0.000000      0.000000
# max    30000.000000  1000000.000000     79.000000      8.000000      8.000000
#
#            JULY_PAY       JUN_PAY       MAY_PAY       APR_PAY      SEPT_BILL  \
# count  30000.000000  30000.000000  30000.000000  30000.000000   30000.000000
# mean      -0.166200     -0.220667     -0.266200     -0.291100   51223.330900
# ...

# %%
#df.mean()# will throw type error

# %%
a=df['LIMIT_BAL'].mean()

# %%
a
# Out:
# np.float64(167484.32266666667)

# %%
b=df['SEPT_PAY'].mean()

# %%
b
# Out:
# np.float64(-0.0167)

# %%
c=df['LIMIT_BAL'].median()

# %%
c
# Out:
# np.float64(140000.0)

# %%
#df.median()# will throw error

# %%
st=df['LIMIT_BAL'].std()

# %%
st
# Out:
# np.float64(129747.66156720239)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()  #entire data info with datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            30000 non-null  int64
#  1   LIMIT_BAL     30000 non-null  float64
#  2   SEX           30000 non-null  object
#  3   EDUCATION     30000 non-null  object
#  4   MARRIAGE      30000 non-null  object
#  5   AGE           30000 non-null  int64
#  6   SEPT_PAY      30000 non-null  int64
#  7   AUG_PAY       30000 non-null  int64
#  8   JULY_PAY      30000 non-null  int64
#  9   JUN_PAY       30000 non-null  int64
#  10  MAY_PAY       30000 non-null  int64
#  11  APR_PAY       30000 non-null  int64
#  12  SEPT_BILL     30000 non-null  int64
#  13  AUG_BILL      30000 non-null  int64
#  14  JULY_BILL     30000 non-null  int64
#  15  JUN_BILL      30000 non-null  int64
#  16  MAY_BILL      30000 non-null  int64
#  17  APR_BILL      30000 non-null  int64
# ...

# %%
numerical_columns=df.select_dtypes(include='number').columns

# %%
numerical_columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'AGE', 'SEPT_PAY', 'AUG_PAY', 'JULY_PAY', 'JUN_PAY',
#        'MAY_PAY', 'APR_PAY', 'SEPT_BILL', 'AUG_BILL', 'JULY_BILL', 'JUN_BILL',
#        'MAY_BILL', 'APR_BILL', 'SEPT_PAYMENT', 'AUG_PAYMENT', 'JULY_PAYMENT',
#        'JUN_PAYMENT', 'MAY_PAYMENT', 'APR_PAYMENT'],
#       dtype='object')

# %%
#skew

# %%
df['LIMIT_BAL'].skew()
# Out:
# np.float64(0.9928669605195444)

# %%
sk=df.select_dtypes(include='number').skew()

# %%
sk
# Out:
# ID               0.000000
# LIMIT_BAL        0.992867
# AGE              0.732246
# SEPT_PAY         0.731975
# AUG_PAY          0.790565
# JULY_PAY         0.840682
# JUN_PAY          0.999629
# MAY_PAY          1.008197
# APR_PAY          0.948029
# SEPT_BILL        2.663861
# AUG_BILL         2.705221
# JULY_BILL        3.087830
# JUN_BILL         2.821965
# MAY_BILL         2.876380
# APR_BILL         2.846645
# SEPT_PAYMENT    14.668364
# AUG_PAYMENT     30.453817
# JULY_PAYMENT    17.216635
# JUN_PAYMENT     12.904985
# MAY_PAYMENT     11.127417
# APR_PAYMENT     10.640727
# dtype: float64

# %%
#data should be normal distributed data

# %%
curk=df.select_dtypes(include='number').kurt()

# %%
curk
# Out:
# ID                -1.200000
# LIMIT_BAL          0.536263
# AGE                0.044303
# SEPT_PAY           2.720715
# AUG_PAY            1.570418
# JULY_PAY           2.084436
# JUN_PAY            3.496983
# MAY_PAY            3.989748
# APR_PAY            3.426534
# SEPT_BILL          9.806289
# AUG_BILL          10.302946
# JULY_BILL         19.783255
# JUN_BILL          11.309325
# MAY_BILL          12.305881
# APR_BILL          12.270705
# SEPT_PAYMENT     415.254743
# AUG_PAYMENT     1641.631911
# JULY_PAYMENT     564.311229
# JUN_PAYMENT      277.333768
# MAY_PAYMENT      180.063940
# APR_PAYMENT      167.161430
# dtype: float64

# %%
#co relation Analysis

# %%
cor=df.select_dtypes(include='number').corr()

# %%
cor
# Out:
#                     ID  LIMIT_BAL       AGE  SEPT_PAY   AUG_PAY  JULY_PAY  \
# ID            1.000000   0.026179  0.018678 -0.030575 -0.011215 -0.018494
# LIMIT_BAL     0.026179   1.000000  0.144713 -0.271214 -0.296382 -0.286123
# AGE           0.018678   0.144713  1.000000 -0.039447 -0.050148 -0.053048
# SEPT_PAY     -0.030575  -0.271214 -0.039447  1.000000  0.672164  0.574245
# AUG_PAY      -0.011215  -0.296382 -0.050148  0.672164  1.000000  0.766552
# JULY_PAY     -0.018494  -0.286123 -0.053048  0.574245  0.766552  1.000000
# JUN_PAY      -0.002735  -0.267460 -0.049722  0.538841  0.662067  0.777359
# MAY_PAY      -0.022199  -0.249411 -0.053826  0.509426  0.622780  0.686775
# APR_PAY      -0.020270  -0.235195 -0.048773  0.474553  0.575501  0.632684
# SEPT_BILL     0.019389   0.285430  0.056239  0.187068  0.234887  0.208473
# AUG_BILL      0.017982   0.278314  0.054283  0.189859  0.235257  0.237295
# JULY_BILL     0.024354   0.283236  0.053710  0.179785  0.224146  0.227494
# ...

# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
AGE=[24,26,34,37]
LIMIT_BAL=[2000,12000,90000,50000]

# %%
plt.plot(AGE,LIMIT_BAL)
plt.title("GRAPH")
plt.xlabel('AGE')
plt.ylabel('LIMIT_BAL')
plt.grid(True)
plt.show()

# %%
categories=[24,26,34,37]
values=[2000,12000,90000,50000]

# %%
plt.bar(categories,values)
plt.xlabel('Age')
plt.ylabel('LIMIT_BAL')
plt.title('BAR DIAGRAM')
# Out:
# Text(0.5, 1.0, 'BAR DIAGRAM')

# %%
i=df['LIMIT_BAL']

# %%
i
# Out:
# 0         20000.0
# 1        120000.0
# 2         90000.0
# 3         50000.0
# 4         50000.0
#            ...
# 29995    220000.0
# 29996    150000.0
# 29997     30000.0
# 29998     80000.0
# 29999     50000.0
# Name: LIMIT_BAL, Length: 30000, dtype: float64

# %%
plt.hist(i,bins=5)
plt.title("HISTOGRAM")
plt.ylabel("LIMIT_BAL")
# Out:
# Text(0, 0.5, 'LIMIT_BAL')

# %%
plt.scatter(AGE,LIMIT_BAL)
plt.title("scatter diagram")
plt.xlabel("AGE")
plt.ylabel("LIMIT_BAL")
plt.grid()

# %%
plt.scatter(AGE,LIMIT_BAL)
plt.plot(AGE,LIMIT_BAL)
plt.title("diagram")
plt.xlabel("AGE")
plt.ylabel("LIMIT_BAL")
plt.grid()

# %%
plt.pie(values,labels=categories,autopct='%1.1f%%')
plt.title("PIE CHART")
# Out:
# Text(0.5, 1.0, 'PIE CHART')
